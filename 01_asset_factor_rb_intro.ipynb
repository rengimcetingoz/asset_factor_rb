# %%
from utils.helpers import *
import pandas as pd
import numpy as np

# %%
np.random.seed(0)

# %% [markdown]
# ### Risk Model
#
# Let's assume the following risk model using which we will be computing various risk-based portfolios:

# %% [markdown]
# $$\Sigma = \beta\Omega\beta' + D $$

# %%
# factor loadings
beta = np.array([[0.9,0,0.5],
                 [1.1,0.5,0], 
                 [1.2,.3,.2],
                 [.8,.1,.7]])

# factor covariance matrix
factor_sigma = np.array([.2,.1,.1])
factor_corr = np.identity(len(factor_sigma))
Omega = factor_corr * (factor_sigma[:,None] @ factor_sigma[:,None].T)

# idiosyncratic covariance matrix
idio_vols = np.array([.1,.15,.1,.15])
D = np.diag(idio_vols**2)

# asset covariance matrix
Sigma = beta@Omega@beta.T+D

# inverse matrices (to avoid computation over again, useful for factor risk contributions of a given portfolio)
pseudo_inv_beta = beta@np.linalg.inv(beta.T@beta)
inv_cov = np.linalg.inv(Sigma)
matrix_min_vol = inv_cov@beta@np.linalg.inv(beta.T@inv_cov@beta) 

d, m = beta.shape

if np.linalg.matrix_rank(beta)!=m:
    raise ValueError('The factor loadings matrix is NOT full rank!')

if is_pos_def(Sigma)==False:
    raise ValueError('The covariance matrix is NOT PSD!')

print('======================================================')
print('Number of assets:', d)
print('Number of factors:', m)
print('======================================================')
print('Betas:', beta)
print('======================================================')
print('Covariance matrix:', Sigma)
# Out:
# ======================================================
# Number of assets: 4
# Number of factors: 3
# ======================================================
# Betas: [[0.9 0.  0.5]
#  [1.1 0.5 0. ]
#  [1.2 0.3 0.2]
#  [0.8 0.1 0.7]]
# ======================================================
# Covariance matrix: [[0.0449 0.0396 0.0442 0.0323]
#  [0.0396 0.0734 0.0543 0.0357]
#  [0.0442 0.0543 0.0689 0.0401]
#  [0.0323 0.0357 0.0401 0.0531]]

# %% [markdown]
# ### Risk Budgeting (RB) portfolio
#
# Optimization problem to find the portfolio whose assets contribute to the total risk (volatility) in proportion to specified risk budgets:
# $$ \min_{y \in \mathbb (R_+^*)^d} y'\Sigma y - \sum_{i=1}^d b_i \log{y_i}$$

# %%
### ERC portfolio
df_erc = pd.DataFrame(index=['Asset 1','Asset 2','Asset 3','Asset 4','Factor 1','Factor 2','Factor 3'],
                     columns=['Exposure', 'Risk Contribution'], dtype='float')


### Optimization problem for ERC portfolio
# asset risk budgets (chosen equal)
budgets = np.ones(d)/d
_, theta_erc = compute_risk_budgeting_portfolio(budgets, Sigma)

# factor allocations of the computed portfolio
w_erc = theta_erc@beta

df_erc.loc[['Asset 1','Asset 2','Asset 3','Asset 4'],'Exposure'] = theta_erc
df_erc.loc[['Factor 1','Factor 2','Factor 3'],'Exposure'] = w_erc

df_erc.loc[['Asset 1','Asset 2','Asset 3','Asset 4'],'Risk Contribution'] =  asset_vol_contribution(theta_erc, Sigma)
df_erc.loc[['Factor 1','Factor 2','Factor 3'],'Risk Contribution'] =  w_erc*grad_factor_risk_measure_volatility_analytical(w_erc, matrix_min_vol, pseudo_inv_beta, Sigma)

df_erc.columns.name = 'ERC'

# %% [markdown]
# ### Factor RB portfolio
#
# Optimization problem to find the portfolio whose factors contribute to the total risk (volatility) in proportion to specified risk budgets:
#
# $$\min_{y \in \mathcal C} y'\Sigma y - \sum_{i=1}^m b_i \log{(\beta'y)_i}$$
#
# where $\mathcal C = \big\{y\in\mathbb{R}^d | (\beta'y)_i>0, \forall i \in \{1,\ldots,m\}\big\}$.

# %%
### Factor ERC portfolio
df_ferc = pd.DataFrame(index=['Asset 1','Asset 2','Asset 3','Asset 4','Factor 1','Factor 2','Factor 3'],
                     columns=['Exposure', 'Risk Contribution'], dtype='float')

### Optimization problem for Factor ERC portfolio
# factor risk budgets (chosen equal)
factor_budgets = np.ones(m)/m
_, theta_ferc = compute_factor_risk_budgeting_portfolio(factor_budgets, beta, Sigma)

# factor allocations of the computed portfolio
w_ferc = theta_ferc@beta

df_ferc.loc[['Asset 1','Asset 2','Asset 3','Asset 4'],'Exposure'] = theta_ferc
df_ferc.loc[['Factor 1','Factor 2','Factor 3'],'Exposure'] = w_ferc

df_ferc.loc[['Asset 1','Asset 2','Asset 3','Asset 4'],'Risk Contribution'] =  asset_vol_contribution(theta_ferc, Sigma)
df_ferc.loc[['Factor 1','Factor 2','Factor 3'],'Risk Contribution'] =  w_ferc*grad_factor_risk_measure_volatility_analytical(w_ferc, matrix_min_vol, pseudo_inv_beta, Sigma)

df_ferc.columns.name = 'FERC'

# %% [markdown]
# ### Asset-Factor RB portfolio
#
# Proposed optimization problem to find the portfolio whose assets and factors contribute to the total risk (volatility) in a balanced way while remaining close to the specified risk budgets:
#
# $$ \min_{y \in \mathcal C^{> 0}} y'\Sigma y  -  \lambda_a \sum_{i=1}^d {b_a}_i \log{y_i} - \lambda_f \sum_{i=1}^m {b_f}_i \log{(\beta'y)_i}$$
# where $\mathcal C^{>0} = \big\{y\in(\mathbb R_+^*)^d | (\beta'y)_i>0, \forall i \in \{1,\ldots,m\}\big\}$ and $\lambda_a, \lambda_f \in \mathbb R_+^*$ are asset and factor importance parameters.

# %%
### Asset-Factor ERC portfolios
df_aferc = pd.DataFrame(index=['Asset 1','Asset 2','Asset 3','Asset 4','Factor 1','Factor 2','Factor 3'],
                     columns=['Exposure', 'Risk Contribution'], dtype='float')

### Optimization problem for Asset-Factor ERC portfolio
# factor risk budgets (chosen equal) and asset risk budgets (chosen equal)
factor_budgets = np.ones(m)/m
asset_budgets = np.ones(d)/d

# factor and asset "importance" parameters
factor_coef = .8
asset_coef = .2

_, theta_aferc = compute_asset_factor_risk_budgeting_portfolio(asset_budgets,
                                                               factor_budgets,
                                                               asset_coef,
                                                               factor_coef,
                                                               beta,
                                                               Sigma)

# factor allocations of the computed portfolio
w_aferc = theta_aferc@beta

df_aferc.loc[['Asset 1','Asset 2','Asset 3','Asset 4'],'Exposure'] = theta_aferc
df_aferc.loc[['Factor 1','Factor 2','Factor 3'],'Exposure'] = w_aferc

df_aferc.loc[['Asset 1','Asset 2','Asset 3','Asset 4'],'Risk Contribution'] =  asset_vol_contribution(theta_aferc, Sigma)
df_aferc.loc[['Factor 1','Factor 2','Factor 3'],'Risk Contribution'] =  w_aferc*grad_factor_risk_measure_volatility_analytical(w_aferc, matrix_min_vol, pseudo_inv_beta, Sigma)

df_aferc.columns.name = 'AFERC'

# %% [markdown]
# ### Nearest Asset-Factor RB portfolios
#
# We propose a framework that automatically calibrates the importance parameters $\lambda_a$ and $\lambda_f$ using Bayesian optimization, aiming to minimize the mean distance between asset and factor risk contributions and their respective budgets.

# %%
### Nearest Asset-Factor ERC portfolios
df_naferc = pd.DataFrame(index=['Asset 1','Asset 2','Asset 3','Asset 4','Factor 1','Factor 2','Factor 3'],
                     columns=['Exposure', 'Risk Contribution'], dtype='float')

### Optimization problem for Nearest Asset-Factor ERC portfolio
# factor risk budgets (chosen equal) and asset risk budgets (chosen equal)
factor_budgets = np.ones(m)/m
asset_budgets = np.ones(d)/d

theta_naferc, opt_lambda_a = compute_nearest_asset_factor_risk_budgeting_portfolio(asset_budgets, 
                                                                                   factor_budgets, 
                                                                                   beta,
                                                                                   Sigma)

# factor allocations of the computed portfolio
w_naferc = theta_naferc@beta

df_naferc.loc[['Asset 1','Asset 2','Asset 3','Asset 4'],'Exposure'] = theta_naferc
df_naferc.loc[['Factor 1','Factor 2','Factor 3'],'Exposure'] = w_naferc

df_naferc.loc[['Asset 1','Asset 2','Asset 3','Asset 4'],'Risk Contribution'] =  asset_vol_contribution(theta_naferc, Sigma)
df_naferc.loc[['Factor 1','Factor 2','Factor 3'],'Risk Contribution'] =  w_naferc*grad_factor_risk_measure_volatility_analytical(w_naferc, matrix_min_vol, pseudo_inv_beta, Sigma)

df_naferc.columns.name = 'NAFERC'
# Out:
# [I 2025-03-24 16:26:41,803] A new study created in memory with name: no-name-bd9e7f24-576b-4b43-8c23-93c27639ea57
# [I 2025-03-24 16:26:41,820] Trial 0 finished with value: 0.8824919071488326 and parameters: {'lamdba_a': 3.668687240870525}. Best is trial 0 with value: 0.8824919071488326.
# [I 2025-03-24 16:26:41,839] Trial 1 finished with value: 0.7268400674932671 and parameters: {'lamdba_a': 0.724359113803278}. Best is trial 1 with value: 0.7268400674932671.
# [I 2025-03-24 16:26:41,854] Trial 2 finished with value: 0.8691913158797797 and parameters: {'lamdba_a': 2.8751806146011383}. Best is trial 1 with value: 0.7268400674932671.
# [I 2025-03-24 16:26:41,865] Trial 3 finished with value: 0.8890157474301229 and parameters: {'lamdba_a': 4.226716726433139}. Best is trial 1 with value: 0.7268400674932671.
# [I 2025-03-24 16:26:41,873] Trial 4 finished with value: 0.8893346185250165 and parameters: {'lamdba_a': 4.258103211916651}. Best is trial 1 with value: 0.7268400674932671.
# [I 2025-03-24 16:26:41,906] Trial 5 finished with value: 0.6811268763253772 and parameters: {'lamdba_a': 0.537495663415856}. Best is trial 5 with value: 0.6811268763253772.
# [I 2025-03-24 16:26:41,920] Trial 6 finished with value: 0.8841540766401049 and parameters: {'lamdba_a': 3.797189909091094}. Best is trial 5 with value: 0.6811268763253772.
# [I 2025-03-24 16:26:41,957] Trial 7 finished with value: 0.8582469157312546 and parameters: {'lamdba_a': 2.4289929506857963}. Best is trial 5 with value: 0.6811268763253772.
# [I 2025-03-24 16:26:41,986] Trial 8 finished with value: 0.8376328299547391 and parameters: {'lamdba_a': 1.860906465486689}. Best is trial 5 with value: 0.6811268763253772.
# [I 2025-03-24 16:26:42,005] Trial 9 finished with value: 0.8291340459306848 and parameters: {'lamdba_a': 1.690935142047346}. Best is trial 5 with value: 0.6811268763253772.
# [I 2025-03-24 16:26:42,024] Trial 10 finished with value: 0.5364953429982204 and parameters: {'lamdba_a': 0.05104272921867442}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,059] Trial 11 finished with value: 0.5454120569892584 and parameters: {'lamdba_a': 0.04561745059841295}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,074] Trial 12 finished with value: 0.5692345227407947 and parameters: {'lamdba_a': 0.2541222869182143}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,092] Trial 13 finished with value: 0.5931179270648245 and parameters: {'lamdba_a': 0.027868100171144074}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,107] Trial 14 finished with value: 0.7911853800888601 and parameters: {'lamdba_a': 1.1753200383227387}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,128] Trial 15 finished with value: 0.7907959255290761 and parameters: {'lamdba_a': 1.1714177204335168}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,141] Trial 16 finished with value: 0.7768275300583514 and parameters: {'lamdba_a': 1.0439113332742878}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,157] Trial 17 finished with value: 0.8315368639450941 and parameters: {'lamdba_a': 1.7361784001140042}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,173] Trial 18 finished with value: 0.8619338700077559 and parameters: {'lamdba_a': 2.564356015250648}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,190] Trial 19 finished with value: 0.8947403179196264 and parameters: {'lamdba_a': 4.866018698877389}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,210] Trial 20 finished with value: 0.6694253377922789 and parameters: {'lamdba_a': 0.4991328677090635}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,226] Trial 21 finished with value: 0.5970882639320964 and parameters: {'lamdba_a': 0.02683977050104245}. Best is trial 10 with value: 0.5364953429982204.
# [I 2025-03-24 16:26:42,242] Trial 22 finished with value: 0.5100159345989949 and parameters: {'lamdba_a': 0.08656347052398888}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,257] Trial 23 finished with value: 0.7434878667263192 and parameters: {'lamdba_a': 0.8129683419652278}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,274] Trial 24 finished with value: 0.6108548075273448 and parameters: {'lamdba_a': 0.34284531787544104}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,291] Trial 25 finished with value: 0.8141961274239725 and parameters: {'lamdba_a': 1.4497556338745838}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,308] Trial 26 finished with value: 0.7257558654493523 and parameters: {'lamdba_a': 0.007877367642466451}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,320] Trial 27 finished with value: 0.7287657149201395 and parameters: {'lamdba_a': 0.7339137928400654}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,340] Trial 28 finished with value: 0.6408051938268058 and parameters: {'lamdba_a': 0.4165060298945534}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,359] Trial 29 finished with value: 0.8474991564578851 and parameters: {'lamdba_a': 2.099485597019185}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,371] Trial 30 finished with value: 0.8740242547277829 and parameters: {'lamdba_a': 3.1233160365448587}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,392] Trial 31 finished with value: 0.5971719047028793 and parameters: {'lamdba_a': 0.3123418227040818}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,408] Trial 32 finished with value: 0.759307844332075 and parameters: {'lamdba_a': 0.9119898598995414}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,427] Trial 33 finished with value: 0.5693472194847733 and parameters: {'lamdba_a': 0.2543496711764692}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,447] Trial 34 finished with value: 0.7145551805125714 and parameters: {'lamdba_a': 0.6671086219070193}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,462] Trial 35 finished with value: 0.8106847645873306 and parameters: {'lamdba_a': 1.4014010935827845}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,479] Trial 36 finished with value: 0.5736042425346433 and parameters: {'lamdba_a': 0.26297009270239596}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,491] Trial 37 finished with value: 0.6952665758603547 and parameters: {'lamdba_a': 0.5882878521907662}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,503] Trial 38 finished with value: 0.8748886729177251 and parameters: {'lamdba_a': 3.1719182929254015}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,521] Trial 39 finished with value: 0.5113708381012412 and parameters: {'lamdba_a': 0.12354193892963754}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,541] Trial 40 finished with value: 0.7579105764205699 and parameters: {'lamdba_a': 0.9025589396010889}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,553] Trial 41 finished with value: 0.5322228717404734 and parameters: {'lamdba_a': 0.17895492964510482}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,572] Trial 42 finished with value: 0.5166392280238565 and parameters: {'lamdba_a': 0.07073149421098823}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,587] Trial 43 finished with value: 0.6811495803271538 and parameters: {'lamdba_a': 0.5375731363775256}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,604] Trial 44 finished with value: 0.5404433585986272 and parameters: {'lamdba_a': 0.19621942948487098}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,622] Trial 45 finished with value: 0.6968914542358935 and parameters: {'lamdba_a': 0.5944739612937322}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,637] Trial 46 finished with value: 0.735468430643006 and parameters: {'lamdba_a': 0.007075537310137825}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,670] Trial 47 finished with value: 0.8028916203168358 and parameters: {'lamdba_a': 1.3031586317338633}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,687] Trial 48 finished with value: 0.7661724953652047 and parameters: {'lamdba_a': 0.9605134918192937}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,704] Trial 49 finished with value: 0.6410318856131842 and parameters: {'lamdba_a': 0.41710761922119877}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,721] Trial 50 finished with value: 0.5337066092671056 and parameters: {'lamdba_a': 0.182136912923801}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,742] Trial 51 finished with value: 0.5300137818590882 and parameters: {'lamdba_a': 0.1741442110162538}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,758] Trial 52 finished with value: 0.5560618341638092 and parameters: {'lamdba_a': 0.22772281170334274}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,774] Trial 53 finished with value: 0.7246461384524514 and parameters: {'lamdba_a': 0.7136745074736832}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,791] Trial 54 finished with value: 0.8862281838244518 and parameters: {'lamdba_a': 3.9699013089231787}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,812] Trial 55 finished with value: 0.5306433749959676 and parameters: {'lamdba_a': 0.17552506539062546}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,829] Trial 56 finished with value: 0.6537634204468818 and parameters: {'lamdba_a': 0.4521613224342928}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,845] Trial 57 finished with value: 0.7850781281549206 and parameters: {'lamdba_a': 1.116414718613435}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,862] Trial 58 finished with value: 0.5170837841784396 and parameters: {'lamdba_a': 0.14266458433440174}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,878] Trial 59 finished with value: 0.7345100737419502 and parameters: {'lamdba_a': 0.7634465267916126}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,900] Trial 60 finished with value: 0.6534666301378095 and parameters: {'lamdba_a': 0.4513143067747684}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,916] Trial 61 finished with value: 0.5123133642802924 and parameters: {'lamdba_a': 0.1273172462722652}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,935] Trial 62 finished with value: 0.7492001288227484 and parameters: {'lamdba_a': 0.006035015100393726}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,955] Trial 63 finished with value: 0.516135902399217 and parameters: {'lamdba_a': 0.1399246453113345}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,959] Trial 64 finished with value: 0.6315146146849255 and parameters: {'lamdba_a': 0.3924695952687455}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,978] Trial 65 finished with value: 0.7020988377861398 and parameters: {'lamdba_a': 0.6148302523402287}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:42,999] Trial 66 finished with value: 0.5145074865240351 and parameters: {'lamdba_a': 0.13492613445166513}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:43,014] Trial 67 finished with value: 0.891701366184057 and parameters: {'lamdba_a': 4.505567058066231}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:43,030] Trial 68 finished with value: 0.6161307028627486 and parameters: {'lamdba_a': 0.355072799564894}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:43,042] Trial 69 finished with value: 0.8435476537463493 and parameters: {'lamdba_a': 1.9977666146597963}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:43,062] Trial 70 finished with value: 0.5113539028061674 and parameters: {'lamdba_a': 0.08185749170812553}. Best is trial 22 with value: 0.5100159345989949.
# [I 2025-03-24 16:26:43,075] Trial 71 finished with value: 0.508616450002007 and parameters: {'lamdba_a': 0.10600143425642211}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,096] Trial 72 finished with value: 0.6710892188045223 and parameters: {'lamdba_a': 0.013609128154538491}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,109] Trial 73 finished with value: 0.6032361547944844 and parameters: {'lamdba_a': 0.32566026045946744}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,132] Trial 74 finished with value: 0.6793605455117833 and parameters: {'lamdba_a': 0.5315059989869755}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,144] Trial 75 finished with value: 0.7455397627286549 and parameters: {'lamdba_a': 0.8249149276028747}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,161] Trial 76 finished with value: 0.5124206518005884 and parameters: {'lamdba_a': 0.12772252654868527}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,179] Trial 77 finished with value: 0.6138453436610972 and parameters: {'lamdba_a': 0.3497416050804297}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,188] Trial 78 finished with value: 0.8575252985180205 and parameters: {'lamdba_a': 2.4040077117938137}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,211] Trial 79 finished with value: 0.7160051165658912 and parameters: {'lamdba_a': 0.6735522147843536}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,228] Trial 80 finished with value: 0.5128532841947683 and parameters: {'lamdba_a': 0.12931549690874383}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,254] Trial 81 finished with value: 0.510308933760893 and parameters: {'lamdba_a': 0.11862189650604223}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,271] Trial 82 finished with value: 0.5851115421468299 and parameters: {'lamdba_a': 0.2866665696798747}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,288] Trial 83 finished with value: 0.6634493181202881 and parameters: {'lamdba_a': 0.48066179549571453}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,296] Trial 84 finished with value: 0.5095861673884107 and parameters: {'lamdba_a': 0.11453562781899784}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,305] Trial 85 finished with value: 0.5832456615031537 and parameters: {'lamdba_a': 0.2827777876401397}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,329] Trial 86 finished with value: 0.8796843650423963 and parameters: {'lamdba_a': 3.469269979718368}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,344] Trial 87 finished with value: 0.5098854235141266 and parameters: {'lamdba_a': 0.08713104201451626}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,364] Trial 88 finished with value: 0.7016887884813581 and parameters: {'lamdba_a': 0.6131971066817061}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,377] Trial 89 finished with value: 0.6635286297952586 and parameters: {'lamdba_a': 0.48090232747330136}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,394] Trial 90 finished with value: 0.5769387734738642 and parameters: {'lamdba_a': 0.26977126062305107}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,412] Trial 91 finished with value: 0.508716293219071 and parameters: {'lamdba_a': 0.09464174892274153}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,421] Trial 92 finished with value: 0.5089049436195452 and parameters: {'lamdba_a': 0.09285974044760917}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,447] Trial 93 finished with value: 0.5600523595898022 and parameters: {'lamdba_a': 0.038751673649406904}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,462] Trial 94 finished with value: 0.6235038480978972 and parameters: {'lamdba_a': 0.37265580828450573}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,478] Trial 95 finished with value: 0.7398044429802692 and parameters: {'lamdba_a': 0.006738222087707982}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,498] Trial 96 finished with value: 0.5661789900373942 and parameters: {'lamdba_a': 0.2479709760511703}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,512] Trial 97 finished with value: 0.5088206915551765 and parameters: {'lamdba_a': 0.10852623314265514}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,529] Trial 98 finished with value: 0.6797897500211308 and parameters: {'lamdba_a': 0.5329546519403308}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,544] Trial 99 finished with value: 0.6268645633957461 and parameters: {'lamdba_a': 0.38086622880688376}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,554] Trial 100 finished with value: 0.8237101318739026 and parameters: {'lamdba_a': 1.5959407648789639}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,571] Trial 101 finished with value: 0.5097364824183839 and parameters: {'lamdba_a': 0.11546194657001518}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,588] Trial 102 finished with value: 0.5456189061041399 and parameters: {'lamdba_a': 0.20676694787814393}. Best is trial 71 with value: 0.508616450002007.
# [I 2025-03-24 16:26:43,604] Trial 103 finished with value: 0.5084418758152707 and parameters: {'lamdba_a': 0.10107564406769352}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,621] Trial 104 finished with value: 0.511243155138373 and parameters: {'lamdba_a': 0.08219161667554789}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,639] Trial 105 finished with value: 0.5692150926711993 and parameters: {'lamdba_a': 0.25408308746885644}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,659] Trial 106 finished with value: 0.6466655809536641 and parameters: {'lamdba_a': 0.43230427213079003}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,679] Trial 107 finished with value: 0.772673008726354 and parameters: {'lamdba_a': 0.004468939182544582}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,697] Trial 108 finished with value: 0.5482868949627304 and parameters: {'lamdba_a': 0.21214869471319459}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,705] Trial 109 finished with value: 0.5084436901014021 and parameters: {'lamdba_a': 0.10024956346927852}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,721] Trial 110 finished with value: 0.7503069310968961 and parameters: {'lamdba_a': 0.8536513245701516}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,738] Trial 111 finished with value: 0.516616469984094 and parameters: {'lamdba_a': 0.07076762125974755}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,754] Trial 112 finished with value: 0.6073893925832845 and parameters: {'lamdba_a': 0.3349624515569922}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,770] Trial 113 finished with value: 0.5096815735149955 and parameters: {'lamdba_a': 0.11512935878775452}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,786] Trial 114 finished with value: 0.5335619624589971 and parameters: {'lamdba_a': 0.18182826149744785}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,801] Trial 115 finished with value: 0.6849277195966673 and parameters: {'lamdba_a': 0.5506402116221117}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,817] Trial 116 finished with value: 0.6118106007492982 and parameters: {'lamdba_a': 0.3450397693337742}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,838] Trial 117 finished with value: 0.5087488004200715 and parameters: {'lamdba_a': 0.10773521558087858}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,855] Trial 118 finished with value: 0.5635963203263139 and parameters: {'lamdba_a': 0.24278916995577887}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,872] Trial 119 finished with value: 0.6444569531217056 and parameters: {'lamdba_a': 0.42628934889153003}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,891] Trial 120 finished with value: 0.798632836381907 and parameters: {'lamdba_a': 0.0030049978753440426}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,908] Trial 121 finished with value: 0.5276134876969575 and parameters: {'lamdba_a': 0.16879672715054678}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,924] Trial 122 finished with value: 0.5089752686629239 and parameters: {'lamdba_a': 0.11001827106679168}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,924] Trial 123 finished with value: 0.5667494957503127 and parameters: {'lamdba_a': 0.24911762448800942}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,940] Trial 124 finished with value: 0.5086482933793336 and parameters: {'lamdba_a': 0.10646372624621675}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,971] Trial 125 finished with value: 0.510426065860582 and parameters: {'lamdba_a': 0.08493561077277656}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:43,986] Trial 126 finished with value: 0.8645324700575274 and parameters: {'lamdba_a': 2.6682794179340106}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,002] Trial 127 finished with value: 0.6007288875468975 and parameters: {'lamdba_a': 0.3201171969531428}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,018] Trial 128 finished with value: 0.7206191600527166 and parameters: {'lamdba_a': 0.6945988753803929}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,033] Trial 129 finished with value: 0.5127297384093528 and parameters: {'lamdba_a': 0.1288670052815354}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,049] Trial 130 finished with value: 0.6498124057910825 and parameters: {'lamdba_a': 0.44100650363091887}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,065] Trial 131 finished with value: 0.5085184052172587 and parameters: {'lamdba_a': 0.09751030571305554}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,080] Trial 132 finished with value: 0.5544950430188134 and parameters: {'lamdba_a': 0.22459148777507543}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,096] Trial 133 finished with value: 0.5086351760925996 and parameters: {'lamdba_a': 0.09561104956550956}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,111] Trial 134 finished with value: 0.7230547399175942 and parameters: {'lamdba_a': 0.00811048926626437}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,143] Trial 135 finished with value: 0.6029730370883438 and parameters: {'lamdba_a': 0.325076057188336}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,158] Trial 136 finished with value: 0.5324562101870322 and parameters: {'lamdba_a': 0.17945776257732537}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,174] Trial 137 finished with value: 0.5128900262398383 and parameters: {'lamdba_a': 0.12944794291721154}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,190] Trial 138 finished with value: 0.687696882608253 and parameters: {'lamdba_a': 0.5604447502560814}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,205] Trial 139 finished with value: 0.5975432963791072 and parameters: {'lamdba_a': 0.3131489801831149}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,221] Trial 140 finished with value: 0.6514225306054717 and parameters: {'lamdba_a': 0.44552099722270455}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,237] Trial 141 finished with value: 0.5107804114509772 and parameters: {'lamdba_a': 0.08367807961798343}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,253] Trial 142 finished with value: 0.5084454552187361 and parameters: {'lamdba_a': 0.1015925943729599}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,268] Trial 143 finished with value: 0.5418580033196859 and parameters: {'lamdba_a': 0.19912003252789634}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,284] Trial 144 finished with value: 0.641814067656131 and parameters: {'lamdba_a': 0.017802617006852914}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,300] Trial 145 finished with value: 0.5644613501191696 and parameters: {'lamdba_a': 0.2445232259662343}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,315] Trial 146 finished with value: 0.5125707885251678 and parameters: {'lamdba_a': 0.12828259454795257}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,331] Trial 147 finished with value: 0.6213713322291757 and parameters: {'lamdba_a': 0.36750804720360764}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,347] Trial 148 finished with value: 0.5824310438013849 and parameters: {'lamdba_a': 0.28108617538725034}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,362] Trial 149 finished with value: 0.7559105262470963 and parameters: {'lamdba_a': 0.005561865772385086}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,378] Trial 150 finished with value: 0.5186195800356741 and parameters: {'lamdba_a': 0.14690262067038695}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,393] Trial 151 finished with value: 0.5093917729867905 and parameters: {'lamdba_a': 0.08958851239400414}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,409] Trial 152 finished with value: 0.5084478720132878 and parameters: {'lamdba_a': 0.10179801768265069}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,425] Trial 153 finished with value: 0.56248142470514 and parameters: {'lamdba_a': 0.24055615534889518}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,440] Trial 154 finished with value: 0.7580836188176259 and parameters: {'lamdba_a': 0.005413008548961554}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,472] Trial 155 finished with value: 0.8945190153074922 and parameters: {'lamdba_a': 4.83794668710329}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,487] Trial 156 finished with value: 0.8532292536968462 and parameters: {'lamdba_a': 2.264545815955632}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,510] Trial 157 finished with value: 0.630625561105226 and parameters: {'lamdba_a': 0.3902300445687399}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,532] Trial 158 finished with value: 0.5258742389752081 and parameters: {'lamdba_a': 0.16482557863409342}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,550] Trial 159 finished with value: 0.6671781019439712 and parameters: {'lamdba_a': 0.4921031223128363}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,573] Trial 160 finished with value: 0.5118864316950797 and parameters: {'lamdba_a': 0.08034684837506684}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,589] Trial 161 finished with value: 0.5084703168908039 and parameters: {'lamdba_a': 0.09878247821397004}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,604] Trial 162 finished with value: 0.5828359968928676 and parameters: {'lamdba_a': 0.28192663057477785}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,620] Trial 163 finished with value: 0.5086445203168779 and parameters: {'lamdba_a': 0.09548970697715127}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,636] Trial 164 finished with value: 0.546616609602372 and parameters: {'lamdba_a': 0.20878290872484745}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,651] Trial 165 finished with value: 0.5099979677084259 and parameters: {'lamdba_a': 0.08663999333697672}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,667] Trial 166 finished with value: 0.6042409973977507 and parameters: {'lamdba_a': 0.3278968331927698}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,695] Trial 167 finished with value: 0.5388699908011952 and parameters: {'lamdba_a': 0.1929739838873828}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,705] Trial 168 finished with value: 0.5107742843232399 and parameters: {'lamdba_a': 0.08369885636487306}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,722] Trial 169 finished with value: 0.6421547237912113 and parameters: {'lamdba_a': 0.017746757968366}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,738] Trial 170 finished with value: 0.5824124672840189 and parameters: {'lamdba_a': 0.2810476425617576}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,755] Trial 171 finished with value: 0.5197700394534133 and parameters: {'lamdba_a': 0.14994514820847513}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,772] Trial 172 finished with value: 0.5086546789085846 and parameters: {'lamdba_a': 0.09536105822512603}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,788] Trial 173 finished with value: 0.5558278698565171 and parameters: {'lamdba_a': 0.22725530707193242}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,803] Trial 174 finished with value: 0.832513299241322 and parameters: {'lamdba_a': 0.0014736162067050668}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,819] Trial 175 finished with value: 0.5088329441250863 and parameters: {'lamdba_a': 0.10865378519041886}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,834] Trial 176 finished with value: 0.6241381114392116 and parameters: {'lamdba_a': 0.3741860904073419}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,850] Trial 177 finished with value: 0.533499278438556 and parameters: {'lamdba_a': 0.18169440432371847}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,866] Trial 178 finished with value: 0.8725551904283563 and parameters: {'lamdba_a': 3.0438146181313996}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,881] Trial 179 finished with value: 0.5085789818454722 and parameters: {'lamdba_a': 0.09641585153256553}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,897] Trial 180 finished with value: 0.5855837146582211 and parameters: {'lamdba_a': 0.2876538655847316}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,912] Trial 181 finished with value: 0.805318097726442 and parameters: {'lamdba_a': 0.0026640792556206078}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,928] Trial 182 finished with value: 0.5088028446949581 and parameters: {'lamdba_a': 0.10833694324747534}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,944] Trial 183 finished with value: 0.536020540332721 and parameters: {'lamdba_a': 0.18703374533986705}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,959] Trial 184 finished with value: 0.5084504474726926 and parameters: {'lamdba_a': 0.09967879103095521}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,975] Trial 185 finished with value: 0.5586895261940467 and parameters: {'lamdba_a': 0.23297303818229875}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:44,991] Trial 186 finished with value: 0.508629843376966 and parameters: {'lamdba_a': 0.095681673582384}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,005] Trial 187 finished with value: 0.6183940372314592 and parameters: {'lamdba_a': 0.3604066907405772}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,021] Trial 188 finished with value: 0.509503699679577 and parameters: {'lamdba_a': 0.11400451159770808}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,037] Trial 189 finished with value: 0.5436662558376743 and parameters: {'lamdba_a': 0.20280712858766856}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,052] Trial 190 finished with value: 0.7230077369854738 and parameters: {'lamdba_a': 0.008114585160141491}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,068] Trial 191 finished with value: 0.5084480084122052 and parameters: {'lamdba_a': 0.09984516383690203}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,083] Trial 192 finished with value: 0.842427737302901 and parameters: {'lamdba_a': 0.0010903754244404595}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,099] Trial 193 finished with value: 0.5128826546628292 and parameters: {'lamdba_a': 0.1294214039130956}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,115] Trial 194 finished with value: 0.5738108628147445 and parameters: {'lamdba_a': 0.26339018190816066}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,130] Trial 195 finished with value: 0.8818392589222362 and parameters: {'lamdba_a': 3.6204406142162116}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,146] Trial 196 finished with value: 0.5110769555153679 and parameters: {'lamdba_a': 0.12226756979959716}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,162] Trial 197 finished with value: 0.6001261152315399 and parameters: {'lamdba_a': 0.3187924056805452}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,177] Trial 198 finished with value: 0.5354209793422468 and parameters: {'lamdba_a': 0.1857718786022538}. Best is trial 103 with value: 0.5084418758152707.
# [I 2025-03-24 16:26:45,193] Trial 199 finished with value: 0.5085255438838081 and parameters: {'lamdba_a': 0.10438863184986119}. Best is trial 103 with value: 0.5084418758152707.

# %%
df_expo  = pd.concat([df_erc[['Exposure']], df_ferc[['Exposure']], df_aferc[['Exposure']], df_naferc[['Exposure']]], axis=1)
df_rc = pd.concat([df_erc[['Risk Contribution']], df_ferc[['Risk Contribution']], df_aferc[['Risk Contribution']], df_naferc[['Risk Contribution']]], axis=1)

df_final = pd.concat([df_expo, df_rc], axis=1)
df_final.columns = [('Exposure (%)', 'RB'), ('Exposure (%)', 'FRB'), ('Exposure (%)', 'AFRB'), ('Exposure (%)', 'NAFRB'),('Risk Contribution (%)', 'RB'), ('Risk Contribution (%)', 'FRB'), ('Risk Contribution (%)', 'AFRB'), ('Risk Contribution (%)', 'NAFRB')]
df_final.columns = pd.MultiIndex.from_tuples(df_final.columns)

df_final_asset = df_final.loc[['Asset 1','Asset 2','Asset 3','Asset 4']]
df_final_asset.loc['Asset sum'] = df_final_asset.sum()
print("Asset allocation")
(df_final_asset*100).round(2)
# Out:
# Asset allocation
#           Exposure (%)                         Risk Contribution (%)         \
#                     RB     FRB    AFRB   NAFRB                    RB    FRB
# Asset 1          27.86   -6.60   18.26   13.13                  5.28  -1.05
# Asset 2          22.60   34.95   25.72   27.85                  5.28   7.93
# Asset 3          21.98    8.87   17.97   14.99                  5.28   1.90
# Asset 4          27.56   62.78   38.05   44.03                  5.28  13.38
# Asset sum       100.00  100.00  100.00  100.00                 21.13  22.16
#
#
#             AFRB  NAFRB
# Asset 1     3.33   2.33
# Asset 2     6.00   6.48
# Asset 3     4.22   3.45
# Asset 4     7.63   9.02
# Asset sum  21.18  21.28

# %%
df_final_factor = df_final.loc[['Factor 1','Factor 2','Factor 3']]
df_final_factor.loc['Factor sum'] = df_final_factor.sum()
print("Factor allocation")
(df_final_factor*100).round(2)
# Out:
# Factor allocation
#            Exposure (%)                         Risk Contribution (%)         \
#                      RB     FRB    AFRB   NAFRB                    RB    FRB
# Factor 1          98.36   93.37   96.73   95.67                 16.64   7.39
# Factor 2          20.65   26.42   22.06   22.83                  1.80   7.39
# Factor 3          37.62   42.42   39.36   40.38                  2.66   7.39
# Factor sum       156.63  162.21  158.15  158.87                 21.11  22.16
#
#
#              AFRB  NAFRB
# Factor 1    13.87  12.23
# Factor 2     3.22   4.09
# Factor 3     4.08   4.94
# Factor sum  21.17  21.27
